# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y=make_regression(n_samples=4, n_features=1, n_informative=1,n_targets=1,noise=80, random_state=13)

# %%
X,y
# Out:
# (array([[-0.71239066],
#         [ 0.45181234],
#         [-0.04450308],
#         [ 0.75376638]]),
#  array([  7.21786552,  16.04609925, -27.83756166, 144.36688189]))

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [78.35063668]
# 26.15963284313262

# %%
y_pred=(78.35 * X + 0).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red")

# %% [markdown]
# ITERATION: 1

# %%
#first line when b=0
y_pred0=(78.35 * X + 0).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red", label='OLS')
plt.plot(X,y_pred0,color='blue', label='b=0')
plt.legend()

# %%
#iteration:1; b=0
m=78.35
lr=0.1
b=0

f_dash_x=-2 * np.sum(y-m * X.ravel() - b)
b=b - lr * f_dash_x
b
# Out:
# np.float64(20.927763408209216)

# %% [markdown]
# ITERATION: 2

# %%
y_pred1=(78.35 * X + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label='OLS') # line from OLS
plt.plot(X,y_pred0,color='blue', label='b0') #line 1st iteration i=0
plt.plot(X,y_pred1,color='green',label='b1') #line 2nd iteration i=1
plt.legend()

# %%
#iteration 2; b=20.927
m=78.35
lr=0.1
b=b

f_dash_x=-2 * np.sum(y-m * X.ravel() - b)
b=b - lr * f_dash_x
b
# Out:
# np.float64(25.11331608985106)

# %% [markdown]
# ITERATION: 2

# %%
y_pred2=(78.35 * X + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label='OLS') # line from OLS
plt.plot(X,y_pred0,color='blue', label='b0') #line 1st iteration i=0
plt.plot(X,y_pred1,color='green',label='b1') #line 2nd iteration i=1
plt.plot(X,y_pred2,color='black',label='b2') #line 3rd iteration i=2
plt.legend()

# %%
#iteration 2; b=20.927
m=78.35
lr=0.1
b=b

f_dash_x=-2 * np.sum(y-m * X.ravel() - b)
b=b - lr * f_dash_x
b
# Out:
# np.float64(25.95042662617943)

# %% [markdown]
# ITERATION: 3

# %%
y_pred3=(78.35 * X + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label='OLS') # line from OLS
plt.plot(X,y_pred0,color='blue', label='b0') #line 1st iteration i=0
plt.plot(X,y_pred1,color='green',label='b1') #line 2nd iteration i=1
plt.plot(X,y_pred2,color='black',label='b2') #line 3rd iteration i=2
plt.plot(X,y_pred3,color='yellow',label='b3') #line 4th iteration i=3
plt.legend()

# %%
m=78.35
lr=0.1
b=b
#SLOPE
f_dash_x=-2 * np.sum(y-m * X.ravel() - b)
#b_new
b=b - lr * f_dash_x
b
# Out:
# np.float64(26.1178487334451)

# %% [markdown]
# LOOP:

# %%
b=-100
m=78.35
lr=0.1

epochs = 10

for i in range(epochs):
    f_dash_x=-2 * np.sum(y-m * X.ravel() - b)
    b=b - lr * f_dash_x

    y_pred= m * X + b

    plt.plot(X,y_pred)

plt.scatter(X,y)
print(y_pred)
# Out:
# [[-29.65611703]
#  [ 61.55918808]
#  [ 22.67287515]
#  [ 85.21728711]]
